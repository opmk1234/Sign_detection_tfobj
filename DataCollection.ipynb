# %%
# !uv add opencv-python
# Out:
# Resolved 121 packages in 2ms
# Audited 101 packages in 15ms

# %%
# !uv add --upgrade pyqt5 lxml
# Out:
# error: Request failed after 3 retries
#   Caused by: Failed to fetch: `https://pypi.org/simple/contextlib2/`
#   Caused by: error sending request for url (https://pypi.org/simple/contextlib2/)
#   Caused by: client error (Connect)
#   Caused by: dns error
#   Caused by: No such host is known. (os error 11001)

# %% [markdown]
# ## Importing Dependencies

# %%
import cv2
import uuid
import os
import time

# %% [markdown]
# ## Defining labels

# %%
labels=['thumbsup','thumbsdown','livelong','thankyou']
number_imgs=5

# %%
Images_path = os.path.join('Tensorflow','workspace','images','collectedimages')

# %%
if not os.path.exists(Images_path):
    if os.name =='posix':
        # !mkdir -p {Images_path}
    if os.name=='nt':
        # !mkdir {Images_path}
for label in labels:
    path=os.path.join(Images_path,label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# ## capturing data

# %%
cap = cv2.VideoCapture(0)

for label in labels:
    print(f'Collecting images for {label}')
    time.sleep(5)

    for image in range(number_imgs):
        print(f'Collecting image {image}')

        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        imgname = os.path.join(Images_path,label,f"{label}.{uuid.uuid1()}.jpg")

        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)

        time.sleep(2)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %%
quick = ['thumbsup','thumbsdown','livelong']
number_imgs=5

# %%
cap = cv2.VideoCapture(0)
#only work if you have team for thankyou 
for label in quick:
    print(f'Collecting images for {label}')
    

    while(True):
        ret, frame = cap.read()
        if not ret:
            print("Failed to grab frame")
            break

        imgname = os.path.join(Images_path,label,f"{label}.{uuid.uuid1()}.jpg")
        if cv2.waitKey(1) & 0xFF == ord('c'):
         cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)



        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Image labelling

# %%
Lable_path = os.path.join("Tensorflow","lableimg")

# %%
if not os.path.exists(Lable_path):
    # !mkdir {Lable_path}
    # !git clone https://github.com/HumanSignal/labelImg {Lable_path}

# %%
if os.name == 'posix':
    ! cd {Lable_path} && make qt5py3
if os.name == 'nt':
    # !cd {Lable_path} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {Lable_path} && python labelImg.py
# Out:
# Image:D:\zMachineLearning\MLProjects\RealObjectDetection\Tensorflow\workspace\images\collectedimages\livelong\livelong.1ad7e918-f9ea-11f0-b6c9-97df86530bb4.jpg -> Annotation:D:/zMachineLearning/MLProjects/RealObjectDetection/Tensorflow/workspace/images/collectedimages/livelong\livelong.1ad7e918-f9ea-11f0-b6c9-97df86530bb4.xml
# Image:D:\zMachineLearning\MLProjects\RealObjectDetection\Tensorflow\workspace\images\collectedimages\livelong\livelong.1b001417-f9ea-11f0-98c0-97df86530bb4.jpg -> Annotation:D:/zMachineLearning/MLProjects/RealObjectDetection/Tensorflow/workspace/images/collectedimages/livelong\livelong.1b001417-f9ea-11f0-98c0-97df86530bb4.xml
# Image:D:\zMachineLearning\MLProjects\RealObjectDetection\Tensorflow\workspace\images\collectedimages\livelong\livelong.1d8fec62-f9ea-11f0-96d1-97df86530bb4.jpg -> Annotation:D:/zMachineLearning/MLProjects/RealObjectDetection/Tensorflow/workspace/images/collectedimages/livelong\livelong.1d8fec62-f9ea-11f0-96d1-97df86530bb4.xml
# ...
